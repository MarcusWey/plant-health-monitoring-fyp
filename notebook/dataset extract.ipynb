# %%
from zipfile import ZipFile
import os

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Path to your ZIP file in Drive
#zip_path = "/content/drive/MyDrive/Marcus Colab/marcus_plant_disease_detection/dataset.zip"
zip_path = "/content/drive/MyDrive/Marcus Colab/marcus_plant_disease_detection/Plant Detection.v1-version-1.yolov9.zip"

# Destination directory
extract_to = "/content/drive/MyDrive/Marcus Colab/marcus_plant_disease_detection/"

# Extract
with ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print("✅ Dataset extracted to", extract_to)
# Out:
# Mounted at /content/drive
# ✅ Dataset extracted to /content/drive/MyDrive/Marcus Colab/marcus_plant_disease_detection/
